# %%
# Initial imports

import os
import requests
import pandas as pd
import numpy as np
import datetime as dt
#import alpaca_trade_api as tradeapi
import seaborn as sns
#from dotenv import load_dotenv
#from MCForecastTools import MCSimulation
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Crypto Selection
# - According to market cap data from yahoo finance
# - Exclude cryptos closely linked to USD, e.g. USDT, USDC etc.
# - Top 6 Cryptos which have the largest market cap

# %% [markdown]
# # Reading the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files (Data from Google Finance and time range from 3-1-2009 to 26-10-2022):
# * BTC
# * ETH
# * BNB
# * XRP
# * ADA
# * SOL

# %%
# Read in price data from CSV files

ada_path = Path("../Resources/ADA.csv")

ada_data = pd.read_csv(ada_path, index_col = 'Date', parse_dates = True,infer_datetime_format = True)

ada_data.index = ada_data.index.date

ada_data = ada_data.rename(columns={'Close':'ADA Close'})


ada_data
# Out:
#             ADA Close
# 2009-05-01     209.89
# 2009-06-01     217.25
# 2009-07-01     213.57
# 2009-08-01     213.57
# 2009-09-01     217.25
# ...               ...
# 2022-03-10       4.50
# 2022-10-13       4.50
# 2022-10-20       4.50
# 2022-10-21       4.50
# 2022-10-24       4.50
#
# [1563 rows x 1 columns]

# %%
ada_data.plot(figsize=(20,10),title='ADA price history')
# Out:
# <AxesSubplot:title={'center':'ADA price history'}>

# %%
# Count nulls
ada_data.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Calculate Daily Returns
ada_daily_return = ada_data.pct_change()

# Rename the column to 'ADA D_Return'

ada_daily_return = ada_daily_return.rename(columns={'Close':'ADA D_Return'})

ada_daily_return
# Out:
#             ADA D_Return
# 2009-05-01           NaN
# 2009-06-01      0.035066
# 2009-07-01     -0.016939
# 2009-08-01      0.000000
# 2009-09-01      0.017231
# ...                  ...
# 2022-03-10     -0.250000
# 2022-10-13      0.000000
# 2022-10-20      0.000000
# 2022-10-21      0.000000
# 2022-10-24      0.000000
#
# [1563 rows x 1 columns]

# %%
# Read in SOL price data from CSV files

sol_path = Path("../Resources/SOL.csv")

sol_data = pd.read_csv(sol_path, index_col = 'Date', parse_dates = True,infer_datetime_format = True)

sol_data.index = sol_data.index.date

sol_data = sol_data.rename(columns={'Close':'SOL Close'})

sol_data
# Out:
#             SOL Close
# 2009-05-01      25.75
# 2009-06-01      25.65
# 2009-07-01      24.35
# 2009-08-01      23.85
# 2009-09-01      23.95
# ...               ...
# 2022-10-19       4.29
# 2022-10-20       4.21
# 2022-10-21       4.25
# 2022-10-24       4.21
# 2022-10-25       4.42
#
# [3478 rows x 1 columns]

# %%
sol_data.plot(figsize=(20,10),title='SOL price history')
# Out:
# <AxesSubplot:title={'center':'SOL price history'}>

# %%
# Count nulls
sol_data.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
sol_daily_return = sol_data.pct_change()

# Rename the column to 'SOL D_Return'

sol_daily_return = sol_daily_return.rename(columns={'Close':'SOL D_Return'})

sol_daily_return
# Out:
#             SOL D_Return
# 2009-05-01           NaN
# 2009-06-01     -0.003883
# 2009-07-01     -0.050682
# 2009-08-01     -0.020534
# 2009-09-01      0.004193
# ...                  ...
# 2022-10-19     -0.042411
# 2022-10-20     -0.018648
# 2022-10-21      0.009501
# 2022-10-24     -0.009412
# 2022-10-25      0.049881
#
# [3478 rows x 1 columns]

# %%
# Read in BTC csv file
btc_path = Path("../Resources/BTC.csv")

btc_data = pd.read_csv(btc_path, index_col = 'Date', parse_dates = True,infer_datetime_format = True)

btc_data.index = btc_data.index.date

btc_data = btc_data.rename(columns={'Close':'BTC Close'})

btc_data
# Out:
#             BTC Close
# 2015-11-19     326.41
# 2015-11-20     322.39
# 2015-11-21     327.00
# 2015-11-22     323.71
# 2015-11-23     323.00
# ...               ...
# 2022-10-21   19173.00
# 2022-10-22   19206.50
# 2022-10-23   19572.40
# 2022-10-24   19330.40
# 2022-10-25   20086.20
#
# [2533 rows x 1 columns]

# %%
btc_data.plot(figsize=(20,10),title='BTC price history')
# Out:
# <AxesSubplot:title={'center':'BTC price history'}>

# %%
# Count nulls
btc_data.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Calculate Daily Returns
btc_daily_return = btc_data.pct_change()

# Rename the column to 'BTC D_Return'

btc_daily_return = btc_daily_return.rename(columns={'Close':'BTC D_Return'})

btc_daily_return
# Out:
#             BTC Close
# 2015-11-19        NaN
# 2015-11-20  -0.012316
# 2015-11-21   0.014299
# 2015-11-22  -0.010061
# 2015-11-23  -0.002193
# ...               ...
# 2022-10-21   0.006943
# 2022-10-22   0.001747
# 2022-10-23   0.019051
# 2022-10-24  -0.012364
# 2022-10-25   0.039099
#
# [2533 rows x 1 columns]

# %%
# Read in BNB csv file
bnb_path = Path("../Resources/BNB.csv")

bnb_data = pd.read_csv(bnb_path, index_col = 'Date', parse_dates = True,infer_datetime_format = True)

bnb_data.index = bnb_data.index.date

bnb_data =bnb_data.rename(columns={'Close':'BNB Close'})

bnb_data
# Out:
#             BNB Close
# 2009-05-01    2401.16
# 2009-06-01    2435.00
# 2009-07-01    2412.06
# 2009-08-01    2419.94
# 2009-09-01    2400.00
# ...               ...
# 2022-10-19     762.00
# 2022-10-20     720.00
# 2022-10-21     750.00
# 2022-10-24     762.00
# 2022-10-25     790.00
#
# [3533 rows x 1 columns]

# %%
bnb_data.plot(figsize=(20,10),title='BNB price history')
# Out:
# <AxesSubplot:title={'center':'BNB price history'}>

# %%
# Count nulls
bnb_data.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Calculate Daily Returns
bnb_daily_return = bnb_data.pct_change()

# Rename the column to 'BNB D_Return'

bnb_daily_return = bnb_daily_return.rename(columns={'Close':'BNB D_Return'})

bnb_daily_return
# Out:
#             BNB D_Return
# 2009-05-01           NaN
# 2009-06-01      0.014093
# 2009-07-01     -0.009421
# 2009-08-01      0.003267
# 2009-09-01     -0.008240
# ...                  ...
# 2022-10-19     -0.047500
# 2022-10-20     -0.055118
# 2022-10-21      0.041667
# 2022-10-24      0.016000
# 2022-10-25      0.036745
#
# [3533 rows x 1 columns]

# %%
# Raad in ETH csv file
eth_path = Path("../Resources/ETH.csv")

eth_data = pd.read_csv(eth_path, index_col = 'Date', parse_dates = True,infer_datetime_format = True)

eth_data.index = eth_data.index.date

eth_data =eth_data.rename(columns={'Close':'ETH Close'})

eth_data
# Out:
#             ETH Close
# 2016-10-14      11.92
# 2016-10-15      11.95
# 2016-10-16      11.95
# 2016-10-17      11.96
# 2016-10-18      12.54
# ...               ...
# 2022-10-22    1313.89
# 2022-10-23    1364.06
# 2022-10-24    1343.75
# 2022-10-25    1460.30
# 2022-10-26    1566.37
#
# [2204 rows x 1 columns]

# %%
eth_data.plot(figsize=(20,10),title='ETH price history')
# Out:
# <AxesSubplot:title={'center':'ETH price history'}>

# %%
# Count nulls
eth_data.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Calculate Daily Returns
eth_daily_return = eth_data.pct_change()

# Rename the column to 'BNB D_Return'

eth_daily_return = eth_daily_return.rename(columns={'Close':'ETH D_Return'})

eth_daily_return
# Out:
#             ETH D_Return
# 2016-10-14           NaN
# 2016-10-15      0.002517
# 2016-10-16      0.000000
# 2016-10-17      0.000837
# 2016-10-18      0.048495
# ...                  ...
# 2022-10-22      0.010630
# 2022-10-23      0.038184
# 2022-10-24     -0.014889
# 2022-10-25      0.086735
# 2022-10-26      0.072636
#
# [2204 rows x 1 columns]

# %%
# Raad in XRP csv file
xrp_path = Path("../Resources/XRP.csv")

xrp_data = pd.read_csv(xrp_path, index_col = 'Date', parse_dates = True,infer_datetime_format = True)

xrp_data.index = xrp_data.index.date

xrp_data =xrp_data.rename(columns={'Close':'XRP Close'})

xrp_data
# Out:
#             XRP Close
# 2017-10-23   0.177415
# 2017-10-24   0.167556
# 2017-10-25   0.170141
# 2017-10-26   0.175370
# 2017-10-27   0.172716
# ...               ...
# 2022-10-22   0.465488
# 2022-10-23   0.469665
# 2022-10-24   0.453703
# 2022-10-25   0.461543
# 2022-10-26   0.469962
#
# [1825 rows x 1 columns]

# %%
xrp_data.plot(figsize=(20,10),title='XRP price history')
# Out:
# <AxesSubplot:title={'center':'XRP price history'}>

# %%
# Count nulls
xrp_data.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
combined_price = pd.concat([btc_data,eth_data,bnb_data,xrp_data,ada_data,sol_data],axis='columns',join = 'inner')
combined_price
# Out:
#             BTC Close  ETH Close  BNB Close  XRP Close  ADA Close  SOL Close
# 2017-10-31    6445.01     303.51    2855.00   0.191211       4.68       2.88
# 2017-12-06   14090.00     432.49    2945.00   0.132274       5.46       2.40
# 2017-12-14   16749.78     705.01    2861.70   0.657867       4.68       2.94
# 2017-12-18   19039.01     785.65    2910.00   0.747993       4.68       3.03
# 2017-12-22   14210.57     682.11    2859.85   1.049011       3.90       2.88
# ...               ...        ...        ...        ...        ...        ...
# 2022-10-06   19965.60    1352.24    1690.00   0.493522       6.00       4.57
# 2022-10-13   19378.60    1288.00     730.00   0.480073       4.50       4.48
# 2022-10-20   19040.80    1282.55     720.00   0.445671       4.50       4.21
# 2022-10-21   19173.00    1300.07     750.00   0.460689       4.50       4.25
# 2022-10-24   19330.40    1343.75     762.00   0.453703       4.50       4.21
#
# [271 rows x 6 columns]

# %%
combined_price.plot(figsize=(20,10),title='Price History of the 6 Cryptos')
# Out:
# <AxesSubplot:title={'center':'Price History of the 6 Cryptos'}>

# %%
# Calculate Daily Returns
xrp_daily_return = xrp_data.pct_change()

# Rename the column to 'BNB D_Return'

xrp_daily_return = xrp_daily_return.rename(columns={'Close':'XRP D_Return'})

xrp_daily_return
# Out:
#             XRP D_Return
# 2017-10-23           NaN
# 2017-10-24     -0.055568
# 2017-10-25      0.015430
# 2017-10-26      0.030730
# 2017-10-27     -0.015134
# ...                  ...
# 2022-10-22      0.010417
# 2022-10-23      0.008975
# 2022-10-24     -0.033987
# 2022-10-25      0.017281
# 2022-10-26      0.018241
#
# [1825 rows x 1 columns]

# %%
# Join All Returns into a single DataFrame with columns for each portfolio's returns.

combined = pd.concat([btc_daily_return,eth_daily_return,bnb_daily_return,xrp_daily_return,ada_daily_return,sol_daily_return],axis='columns',join = 'inner')

combined.dropna(inplace=True)
combined
# Out:
#             BTC D_Return  ETH D_Return  BNB D_Return  XRP D_Return  \
# 2017-10-31      0.083333     -0.010949     -0.005209      0.044092
# 2017-12-06      0.000000     -0.054253     -0.015034     -0.437412
# 2017-12-18      0.000000      0.073028      0.018105      0.363291
# 2017-12-22      0.111111     -0.144132      0.000297      0.120486
# 2018-01-03      0.000000      0.084751     -0.003333      0.343338
# ...                  ...           ...           ...           ...
# 2022-10-03      0.200000      0.036401     -0.003049      0.030378
# 2022-10-13      0.000000     -0.005021      0.102719     -0.015899
# 2022-10-20      0.000000     -0.001852     -0.055118     -0.012772
# 2022-10-21     -0.166667      0.013660      0.041667      0.033697
# 2022-10-24      0.200000     -0.014889      0.016000     -0.033987
#
#             ADA D_Return  SOL D_Return
# 2017-10-31      0.000000     -0.013699
# 2017-12-06     -0.176471      0.016949
# 2017-12-18      0.000000      0.023649
# 2017-12-22     -0.166667      0.006993
# 2018-01-03      0.000000      0.000000
# ...                  ...           ...
# 2022-10-03      0.000000     -0.007310
# 2022-10-13      0.000000      0.000000
# 2022-10-20      0.000000     -0.018648
# 2022-10-21      0.000000      0.009501
# 2022-10-24      0.000000     -0.009412
#
# [201 rows x 6 columns]

# %%
# plot the daily return of the 6 cryptos

combined.plot(figsize=(20,10),title='Daily Return of All Portfolios')
# Out:
# <AxesSubplot:title={'center':'Daily Return of All Portfolios'}>

# %%
# Calculate cumulative returns of the 6 cryptos

cumulative_return = (1 + combined).cumprod()-1

cumulative_return
# Out:
#             BTC D_Return  ETH D_Return  BNB D_Return  XRP D_Return  \
# 2017-10-31      0.083333     -0.010949     -0.005209      0.044092
# 2017-12-06      0.083333     -0.064608     -0.020165     -0.412606
# 2017-12-18      0.083333      0.003702     -0.002424     -0.199211
# 2017-12-22      0.203704     -0.140963     -0.002128     -0.102727
# 2018-01-03      0.203704     -0.068159     -0.005454      0.205340
# ...                  ...           ...           ...           ...
# 2022-10-03      1.965355      0.387579     -0.537663      0.796213
# 2022-10-13      1.965355      0.380611     -0.490172      0.767654
# 2022-10-20      1.965355      0.378054     -0.518273      0.745078
# 2022-10-21      1.471129      0.396879     -0.498201      0.803882
# 2022-10-24      1.965355      0.376080     -0.490172      0.742574
#
#             ADA D_Return  SOL D_Return
# 2017-10-31      0.000000     -0.013699
# 2017-12-06     -0.176471      0.003018
# 2017-12-18     -0.176471      0.026738
# 2017-12-22     -0.313725      0.033918
# 2018-01-03     -0.313725      0.033918
# ...                  ...           ...
# 2022-10-03      0.055206     -0.124434
# 2022-10-13      0.055206     -0.124434
# 2022-10-20      0.055206     -0.140761
# 2022-10-21      0.055206     -0.132598
# 2022-10-24      0.055206     -0.140761
#
# [201 rows x 6 columns]

# %%
cumulative_return.index
# Out:
# Index([2017-10-31, 2017-12-06, 2017-12-18, 2017-12-22, 2018-01-03, 2018-03-27,
#        2018-05-03, 2018-05-04, 2018-05-23, 2018-06-11,
#        ...
#        2022-09-21, 2022-09-23, 2022-09-26, 2022-09-27, 2022-09-28, 2022-10-03,
#        2022-10-13, 2022-10-20, 2022-10-21, 2022-10-24],
#       dtype='object', length=201)

# %%
# Plot cumulative returns

cumulative_return.plot()
# Out:
# <AxesSubplot:>

# %%
# plot the moving average

# %%
# plot the volatilities of the 6 cryptos

# %%
# plot the Sharpe Ratio of the 6 cryptos

# %%
# Calculate the daily standard deviations

combined_std = combined.std()
combined_std
# Out:
# BTC D_Return    0.134449
# ETH D_Return    0.059259
# BNB D_Return    0.026404
# XRP D_Return    0.081261
# ADA D_Return    0.204299
# SOL D_Return    0.065426
# dtype: float64

# %%
# Plot the Standard Deviation of the 6 Cryptos

combined_std.plot(kind = 'bar',title='Standard Deviation of the 6 Cryptos')
# Out:
# <AxesSubplot:title={'center':'Standard Deviation of the 6 Cryptos'}>

# %%
# plot the rolling std (30 days, 60 days) of the 6 cryptos

# %%
# plot the heatmap

# %%
# CVI - crypto volatility index

# %%
# S&P (SPY) and ASX

# %%
# Porforlios : do some research

# %%
# 52 weeks in one year, 52*5/12 = 65 months
# suppose we started investing from the first date in the dataframe which is 2017-10-31 and invest $100 every month

cal_times = 0
i = 0
amount = 0


while cal_times < 65:

        print(btc_data_slice.index[i])
        price = btc_data_slice.iloc[i,0]

        amount = amount + 100/price
        
        print(price,amount)
    
        i = i + 28
    
        cal_times += 1
    
        print(cal_times)
    
last_date_time =  btc_data_slice.index[i-28]
last_price_btc = btc_data_slice.iloc[i-28,0]

print(f'total amount of btc:{amount}')
print(f'last date time is:{last_date_time}')
print(f'last price of btc is:{last_price_btc}')

dca_btc_value = amount * last_price_btc

dca_btc_value
# Out:
# 2017-08-30
# 4581.98 0.021824626035032893
# 1
# 2017-09-27
# 4200.0 0.0456341498445567
# 2
# 2017-10-25
# 5739.97 0.06305584368616214
# 3
# 2017-11-22
# 8250.0 0.07517705580737426
# 4
# 2017-12-20
# 16496.89 0.08123880441574832
# 5
# 2018-01-17
# 11200.01 0.09016736787238809
# 6
# 2018-02-14
# 9472.98 0.10072370811590176
# 7
# 2018-03-14
# 8207.02 0.11290839878315978
# 8
# 2018-04-11
# 6942.99 0.12731141535094975
# 9
# 2018-05-09
# 9300.08 0.1380640110275461
# 10
# 2018-06-06
# 7655.0 0.15112736831036777
# 11
# 2018-07-04
# 6587.47 0.16630770309747117
# 12
# 2018-08-01
# 7603.99 0.17945869356431818
# 13
# 2018-08-29
# 7030.9 0.19368162377239964
# 14
# 2018-09-26
# 6455.66 0.20917190671790792
# 15
# 2018-10-24
# 6415.98 0.22475799021567444
# 16
# 2018-11-21
# 4545.11 0.2467596579420881
# 17
# 2018-12-19
# 3682.51 0.273915049237699
# 18
# 2019-01-16
# 3609.71 0.30161810571592024
# 19
# 2019-02-13
# 3576.68 0.3295769949651681
# 20
# 2019-03-13
# 3851.02 0.35554414133158535
# 21
# 2019-04-10
# 5320.81 0.3743382723003664
# 22
# 2019-05-08
# 5943.6 0.3911630922747927
# 23
# 2019-06-05
# 7789.48 0.40400091970358126
# 24
# 2019-07-03
# 11976.0 0.4123509531037149
# 25
# 2019-07-31
# 10086.3 0.4222653915003519
# 26
# 2019-08-28
# 9714.31 0.432559483412181
# 27
# 2019-09-25
# 8438.35 0.4444101414199669
# 28
# 2019-10-23
# 7474.85 0.4577883363001317
# 29
# 2019-11-20
# 8082.96 0.4701600417149797
# 30
# 2019-12-18
# 7294.81 0.483868417944107
# 31
# 2020-01-15
# 8808.81 0.49522068913624306
# 32
# 2020-02-12
# 10351.1 0.5048814981323884
# 33
# 2020-03-11
# 7938.05 0.5174790504279774
# 34
# 2020-04-08
# 7370.11 0.5310473689469682
# 35
# 2020-05-06
# 9157.11 0.5419678449486762
# 36
# 2020-06-03
# 9655.62 0.5523245077005243
# 37
# 2020-07-01
# 9239.96 0.5631470653739342
# 38
# 2020-07-29
# 11098.8 0.572157048435166
# 39
# 2020-08-26
# 11463.2 0.5808806160253677
# 40
# 2020-09-23
# 10235.1 0.5906509162666941
# 41
# 2020-10-21
# 12844.4 0.5984364103341476
# 42
# 2020-11-18
# 17845.5 0.6040400639162832
# 43
# 2020-12-16
# 21359.6 0.6087217995293096
# 44
# 2021-01-13
# 37369.0 0.6113978144079524
# 45
# 2021-02-10
# 44850.0 0.6136274688115199
# 46
# 2021-03-10
# 55972.8 0.6154140508656605
# 47
# 2021-04-07
# 55955.7 0.6172011788972998
# 48
# 2021-05-05
# 57515.6 0.6189398376264098
# 49
# 2021-06-02
# 37581.8 0.6216007000651435
# 50
# 2021-06-30
# 35069.6 0.6244521725655426
# 51
# 2021-07-28
# 40035.1 0.6269499807388705
# 52
# 2021-08-25
# 48987.3 0.6289913261488033
# 53
# 2021-09-22
# 43575.1 0.6312862147434365
# 54
# 2021-10-20
# 66017.7 0.6328009600314426
# 55
# 2021-11-17
# 60394.9 0.6344567289788205
# 56
# 2021-12-15
# 48884.7 0.6365023587975573
# 57
# 2022-01-12
# 43921.8 0.6387791325181243
# 58
# 2022-02-09
# 44339.6 0.6410344528187134
# 59
# 2022-03-09
# 41980.1 0.643416533852346
# 60
# 2022-04-06
# 43170.3 0.6457329411972104
# 61
# 2022-05-04
# 39669.5 0.6482537695414042
# 62
# 2022-06-01
# 29788.7 0.6516107471872901
# 63
# 2022-06-29
# 20093.5 0.6565874809569171
# 64
# 2022-07-27
# 22949.6 0.6609448553773863
# 65
# total amount of btc:0.6609448553773863
# last date time is:2022-07-27
# last price of btc is:22949.6
# 15168.420052968864

# %%
btc_daily_return.describe()
btc_cumprod = (btc_daily_return+1).cumprod()-1
btc_cumprod.reset_index()
btc_cumprod['Date'] = pd.to_datetime(btc_cumprod['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2504\4265680368.py in <module>
#       2 btc_cumprod = (btc_daily_return+1).cumprod()-1
#       3 btc_cumprod.reset_index()
# ----> 4 btc_cumprod['Date'] = pd.to_datetime(btc_cumprod['Date'])
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Date'

# %%
btc_cumprod = btc_cumprod.set_index(pd.to_datetime(btc_cumprod['Date']))



#print(btc_cumprod.columns)
#print(btc_cumprod.index)
#btc_cumprod['Date']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2504\698804992.py in <module>
# ----> 1 btc_cumprod = btc_cumprod.set_index(pd.to_datetime(btc_cumprod['Date']))
#       2
#       3
#       4
#       5 #print(btc_cumprod.columns)
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Date'

# %%
# Out:
#             btc close
# Date
# 2015-11-19        NaN
# 2015-11-20  -0.012316
# 2015-11-21   0.001808
# 2015-11-22  -0.008272
# 2015-11-23  -0.010447
# ...               ...
# 2022-10-21  57.739009
# 2022-10-22  57.841641
# 2022-10-23  58.962624
# 2022-10-24  58.221225
# 2022-10-25  60.536718
#
# [2533 rows x 1 columns]

# %%
last_date_time
#btc_cumprod.loc[['2022-07-27']]
btc_cumprod.loc[[2015-11-20]]

#btc_cumprod[2400:2450]

#people_csv.iloc[0, people_csv.columns.get_loc('first_name')] = 'Arya'
#print(btc_cumprod.loc[btc_cumprod['Date']=='2022-07-27'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2504\431071483.py in <module>
#       1 last_date_time
#       2 #btc_cumprod.loc[['2022-07-27']]
# ----> 3 btc_cumprod.loc[[pd.dt('2015-11-20')]]
#       4
#       5 #btc_cumprod[2400:2450]
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'dt'

# %%
# A Lump Sum Investment Vs. DCA(Dollar-Cost Averaging) Investment Comparison

# $6500 in the beginning Vs. $100 per month from 2017-2022

# (52*5/4)*100 = 6500

last_date_time

initail_amount = 6500

#cum_return_btc = btc_cumprod.loc[btc_cumprod.get_loc(btc_cumprod.Date == pd.dt(last_date_time))]
btc_cumprod.index[pd.dt.last_date_time]

#cum_return_btc

#cum_return_btc = 1.965355

#compound_return_btc = initail_amount * cum_return_btc


#compound_return_btc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2504\2258312116.py in <module>
#      10
#      11 #cum_return_btc = btc_cumprod.loc[btc_cumprod.get_loc(btc_cumprod.Date == pd.dt(last_date_time))]
# ---> 12 btc_cumprod.index[pd.dt.last_date_time]
#      13
#      14 #cum_return_btc
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'dt'

# %%
# within 5 years time period, get the close price once every month, calculate the amount by 100/close_price
# get the sum amount and calculate the value by the final close price*sum_amount

# %%
btc_data
# Out:
#             BTC Close
# 2015-11-19     326.41
# 2015-11-20     322.39
# 2015-11-21     327.00
# 2015-11-22     323.71
# 2015-11-23     323.00
# ...               ...
# 2022-10-21   19173.00
# 2022-10-22   19206.50
# 2022-10-23   19572.40
# 2022-10-24   19330.40
# 2022-10-25   20086.20
#
# [2533 rows x 1 columns]

# %%
btc_data_slice = btc_data[650:]
btc_data_slice
# Out:
#             BTC Close
# 2017-08-30    4581.98
# 2017-08-31    4743.94
# 2017-09-01    4947.99
# 2017-09-02    4649.99
# 2017-09-03    4626.05
# ...               ...
# 2022-10-21   19173.00
# 2022-10-22   19206.50
# 2022-10-23   19572.40
# 2022-10-24   19330.40
# 2022-10-25   20086.20
#
# [1883 rows x 1 columns]

# %%
# Out:
# 2017-08-30
# 4581.98 0.021824626035032893
# 1
# 2017-09-27
# 4200.0 0.0456341498445567
# 2
# 2017-10-25
# 5739.97 0.06305584368616214
# 3
# 2017-11-22
# 8250.0 0.07517705580737426
# 4
# 2017-12-20
# 16496.89 0.08123880441574832
# 5
# 2018-01-17
# 11200.01 0.09016736787238809
# 6
# 2018-02-14
# 9472.98 0.10072370811590176
# 7
# 2018-03-14
# 8207.02 0.11290839878315978
# 8
# 2018-04-11
# 6942.99 0.12731141535094975
# 9
# 2018-05-09
# 9300.08 0.1380640110275461
# 10
# 2018-06-06
# 7655.0 0.15112736831036777
# 11
# 2018-07-04
# 6587.47 0.16630770309747117
# 12
# 2018-08-01
# 7603.99 0.17945869356431818
# 13
# 2018-08-29
# 7030.9 0.19368162377239964
# 14
# 2018-09-26
# 6455.66 0.20917190671790792
# 15
# 2018-10-24
# 6415.98 0.22475799021567444
# 16
# 2018-11-21
# 4545.11 0.2467596579420881
# 17
# 2018-12-19
# 3682.51 0.273915049237699
# 18
# 2019-01-16
# 3609.71 0.30161810571592024
# 19
# 2019-02-13
# 3576.68 0.3295769949651681
# 20
# 2019-03-13
# 3851.02 0.35554414133158535
# 21
# 2019-04-10
# 5320.81 0.3743382723003664
# 22
# 2019-05-08
# 5943.6 0.3911630922747927
# 23
# 2019-06-05
# 7789.48 0.40400091970358126
# 24
# 2019-07-03
# 11976.0 0.4123509531037149
# 25
# 2019-07-31
# 10086.3 0.4222653915003519
# 26
# 2019-08-28
# 9714.31 0.432559483412181
# 27
# 2019-09-25
# 8438.35 0.4444101414199669
# 28
# 2019-10-23
# 7474.85 0.4577883363001317
# 29
# 2019-11-20
# 8082.96 0.4701600417149797
# 30
# 2019-12-18
# 7294.81 0.483868417944107
# 31
# 2020-01-15
# 8808.81 0.49522068913624306
# 32
# 2020-02-12
# 10351.1 0.5048814981323884
# 33
# 2020-03-11
# 7938.05 0.5174790504279774
# 34
# 2020-04-08
# 7370.11 0.5310473689469682
# 35
# 2020-05-06
# 9157.11 0.5419678449486762
# 36
# 2020-06-03
# 9655.62 0.5523245077005243
# 37
# 2020-07-01
# 9239.96 0.5631470653739342
# 38
# 2020-07-29
# 11098.8 0.572157048435166
# 39
# 2020-08-26
# 11463.2 0.5808806160253677
# 40
# 2020-09-23
# 10235.1 0.5906509162666941
# 41
# 2020-10-21
# 12844.4 0.5984364103341476
# 42
# 2020-11-18
# 17845.5 0.6040400639162832
# 43
# 2020-12-16
# 21359.6 0.6087217995293096
# 44
# 2021-01-13
# 37369.0 0.6113978144079524
# 45
# 2021-02-10
# 44850.0 0.6136274688115199
# 46
# 2021-03-10
# 55972.8 0.6154140508656605
# 47
# 2021-04-07
# 55955.7 0.6172011788972998
# 48
# 2021-05-05
# 57515.6 0.6189398376264098
# 49
# 2021-06-02
# 37581.8 0.6216007000651435
# 50
# 2021-06-30
# 35069.6 0.6244521725655426
# 51
# 2021-07-28
# 40035.1 0.6269499807388705
# 52
# 2021-08-25
# 48987.3 0.6289913261488033
# 53
# 2021-09-22
# 43575.1 0.6312862147434365
# 54
# 2021-10-20
# 66017.7 0.6328009600314426
# 55
# 2021-11-17
# 60394.9 0.6344567289788205
# 56
# 2021-12-15
# 48884.7 0.6365023587975573
# 57
# 2022-01-12
# 43921.8 0.6387791325181243
# 58
# 2022-02-09
# 44339.6 0.6410344528187134
# 59
# 2022-03-09
# 41980.1 0.643416533852346
# 60
# 2022-04-06
# 43170.3 0.6457329411972104
# 61
# 2022-05-04
# 39669.5 0.6482537695414042
# 62
# 2022-06-01
# 29788.7 0.6516107471872901
# 63
# 2022-06-29
# 20093.5 0.6565874809569171
# 64
# 2022-07-27
# 22949.6 0.6609448553773863
# 65
# total amount of btc:0.6609448553773863
# last date time is:2022-07-27
# last price of btc is:22949.6
# 15168.420052968864

# %%
# Monte Carlo Simulation in 1, 5, 10 years of different poforlios
