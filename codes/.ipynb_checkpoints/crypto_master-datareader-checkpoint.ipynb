# %%
# Initial imports

import os
import requests
import pandas as pd
import numpy as np
import datetime as dt
import alpaca_trade_api as tradeapi
import seaborn as sns
from dotenv import load_dotenv
from MCForecastTools import MCSimulation
from pathlib import Path

import matplotlib.pyplot as plt

from pandas_datareader import data as pdr

# %matplotlib inline

# %% [markdown]
# # Reading the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files (Data from Google Finance and time range from 3-1-2009 to 26-10-2022):
# * BTC
# * ETH
# * BNB
# * XRP
# * ADA
# * SOL

# %%
# Read in crypto price data 

start= pd.to_datetime('2017-08-01')
end=pd.to_datetime('2022-09-01')

ada_data = pdr.get_data_yahoo('ADA-USD', start, end)
btc_data = pdr.get_data_yahoo('BTC-USD', start, end)
eth_data = pdr.get_data_yahoo('ETH-USD', start, end)
sol_data = pdr.get_data_yahoo('SOL-USD', start, end)
xrp_data = pdr.get_data_yahoo('XRP-USD', start, end)
bnb_data = pdr.get_data_yahoo('BNB-USD', start, end)

sol_data
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2020-04-10   1.313487   0.694187   0.832005   0.951054   87364276   0.951054
# 2020-04-11   1.049073   0.765020   0.951054   0.776819   43862444   0.776819
# 2020-04-12   0.956670   0.762426   0.785448   0.882507   38736897   0.882507
# 2020-04-13   0.891603   0.773976   0.890760   0.777832   18211285   0.777832
# 2020-04-14   0.796472   0.628169   0.777832   0.661925   16747614   0.661925
# ...               ...        ...        ...        ...        ...        ...
# 2022-08-28  32.129612  30.388781  31.538864  30.392286  562501615  30.392286
# 2022-08-29  32.520748  30.119162  30.393860  32.465298  891913484  32.465298
# 2022-08-30  33.072636  30.796524  32.460041  31.412056  861409804  31.412056
# 2022-08-31  32.876423  31.237885  31.416515  31.472956  769308937  31.472956
# 2022-09-01  31.709314  30.511267  31.475082  31.585678  666487074  31.585678
#
# [875 rows x 6 columns]

# %% [markdown]
# # Crypto Selection
# - According to market cap data from yahoo finance
# - Exclude cryptos closely linked to USD, e.g. USDT, USDC etc.
# - Top 6 Cryptos which have the largest market cap

# %%
ada_data = read_crypto_price('ADA')
btc_data = read_crypto_price('BTC')
eth_data = read_crypto_price('ETH')
sol_data = read_crypto_price('SOL')
xrp_data = read_crypto_price('XRP')
bnb_data = read_crypto_price('BNB')

# %% [markdown]
# # Data concatination, plotting and analysis

# %%
# Combine all the price data into one dataframe
combined_price = pd.concat([btc_data,eth_data,bnb_data,xrp_data,ada_data,sol_data],axis='columns',join = 'inner')
combined_price
# Out:
#             BTC Close  ETH Close  BNB Close  XRP Close  ADA Close  SOL Close
# 2017-11-28    9949.00     468.52    2873.95   0.198750   0.099375       3.66
# 2017-11-29    9935.98     434.01    2879.60   0.203189   0.101595       3.49
# 2017-11-30    9903.00     434.00    2894.75   0.193549   0.096775       3.53
# 2017-12-01   10869.84     463.82    3001.00   0.216402   0.108201       3.38
# 2017-12-04   11643.98     468.22    2991.85   0.229385   0.114692       2.57
# ...               ...        ...        ...        ...        ...        ...
# 2022-10-19   19128.30    1284.93     762.00   0.451437   0.350320       4.29
# 2022-10-20   19040.80    1282.55     720.00   0.445671   0.339866       4.21
# 2022-10-21   19173.00    1300.07     750.00   0.460689   0.348578       4.25
# 2022-10-24   19330.40    1343.75     762.00   0.453703   0.358074       4.21
# 2022-10-25   20086.20    1460.30     790.00   0.461543   0.402476       4.42
#
# [1206 rows x 6 columns]

# %%
# plot the price history of the 6 cryptos
combined_price.plot(figsize=(20,10),title='Price History of the 6 Cryptos')
# Out:
# <AxesSubplot:title={'center':'Price History of the 6 Cryptos'}>

# %%
# Calculate Daily Returns
combined_daily_return = combined_price.pct_change()

# Rename the column to 'XXX D_Return'
combined_daily_return = combined_daily_return.rename(
    columns=
    {
        'BTC Close':'BTC D_Return',
        'ETH Close':'ETH D_Return',
        'BNB Close':'BNB D_Return',
        'XRP Close':'XRP D_Return',
        'ADA Close':'ADA D_Return',
        'SOL Close':'SOL D_Return'
    }
)
combined_daily_return.dropna(inplace=True)
combined_daily_return
# Out:
#             BTC D_Return  ETH D_Return  BNB D_Return  XRP D_Return  \
# 2017-11-29     -0.001309     -0.073657      0.001966      0.022335
# 2017-11-30     -0.003319     -0.000023      0.005261     -0.047442
# 2017-12-01      0.097631      0.068710      0.036704      0.118073
# 2017-12-04      0.071219      0.009486     -0.003049      0.059991
# 2017-12-05      0.006387     -0.023322      0.019436      0.024990
# ...                  ...           ...           ...           ...
# 2022-10-19     -0.010445     -0.020580     -0.047500     -0.031579
# 2022-10-20     -0.004574     -0.001852     -0.055118     -0.012772
# 2022-10-21      0.006943      0.013660      0.041667      0.033697
# 2022-10-24      0.008209      0.033598      0.016000     -0.015164
# 2022-10-25      0.039099      0.086735      0.036745      0.017281
#
#             ADA D_Return  SOL D_Return
# 2017-11-29      0.022335     -0.046448
# 2017-11-30     -0.047442      0.011461
# 2017-12-01      0.118073     -0.042493
# 2017-12-04      0.059991     -0.239645
# 2017-12-05      0.024990      0.081712
# ...                  ...           ...
# 2022-10-19     -0.028594     -0.042411
# 2022-10-20     -0.029841     -0.018648
# 2022-10-21      0.025633      0.009501
# 2022-10-24      0.027241     -0.009412
# 2022-10-25      0.124003      0.049881
#
# [1205 rows x 6 columns]

# %%
# plot the daily return of the 6 cryptos
combined_daily_return.plot(figsize=(20,10),title='Daily Return of All Cryptos')
# Out:
# <AxesSubplot:title={'center':'Daily Return of All Cryptos'}>

# %%
# Calculate cumulative returns of the 6 cryptos
cumulative_return = (1 + combined_daily_return).cumprod()-1

cumulative_return
# Out:
#             BTC D_Return  ETH D_Return  BNB D_Return  XRP D_Return  \
# 2017-11-29     -0.001309     -0.073657      0.001966      0.022335
# 2017-11-30     -0.004624     -0.073679      0.007237     -0.026168
# 2017-12-01      0.092556     -0.010032      0.044207      0.088816
# 2017-12-04      0.170367     -0.000640      0.041024      0.154135
# 2017-12-05      0.177842     -0.023948      0.061257      0.182977
# ...                  ...           ...           ...           ...
# 2022-10-19      0.922635      1.742530     -0.734860      1.271376
# 2022-10-20      0.913841      1.737450     -0.749474      1.242367
# 2022-10-21      0.927128      1.774844     -0.739035      1.317928
# 2022-10-24      0.942949      1.868074     -0.734860      1.282780
# 2022-10-25      1.018916      2.116836     -0.725117      1.322228
#
#             ADA D_Return  SOL D_Return
# 2017-11-29      0.022335     -0.046448
# 2017-11-30     -0.026168     -0.035519
# 2017-12-01      0.088816     -0.076503
# 2017-12-04      0.154135     -0.297814
# 2017-12-05      0.182977     -0.240437
# ...                  ...           ...
# 2022-10-19      2.525230      0.172131
# 2022-10-20      2.420033      0.150273
# 2022-10-21      2.507700      0.161202
# 2022-10-24      2.603252      0.150273
# 2022-10-25      3.050067      0.207650
#
# [1205 rows x 6 columns]

# %%
cumulative_return.describe()
# Out:
#        BTC D_Return  ETH D_Return  BNB D_Return  XRP D_Return  ADA D_Return  \
# count   1205.000000   1205.000000   1205.000000   1205.000000   1205.000000
# mean       1.029206      1.385053     -0.260639      1.611746      3.997477
# std        1.729985      2.587709      0.164317      1.724216      6.453568
# min       -0.678791     -0.822846     -0.773135     -0.334471     -0.764940
# 25%       -0.233443     -0.560040     -0.396301      0.407660     -0.368465
# 50%        0.062074     -0.010032     -0.293655      0.967063      0.460097
# 75%        2.393738      2.851874     -0.140556      2.416751      6.957832
# max        5.792904      9.285516      0.064737     12.963452     28.827390
#
#        SOL D_Return
# count   1205.000000
# mean       0.177101
# std        1.166623
# min       -0.765027
# 25%       -0.581967
# 50%       -0.314208
# 75%        0.633880
# max        8.166667

# %%
# Plot cumulative return of all the cryptos
cumulative_return.plot(figsize=(20,10),title='Cumulative Return of All Cryptos')
# Out:
# <AxesSubplot:title={'center':'Cumulative Return of All Cryptos'}>

# %%
# Calculate the daily standard deviations

combined_std = combined_daily_return.std()
combined_std
# Out:
# BTC D_Return    0.048320
# ETH D_Return    0.063473
# BNB D_Return    0.106281
# XRP D_Return    0.091384
# ADA D_Return    0.087791
# SOL D_Return    0.289993
# dtype: float64

# %%
# Plot the Standard Deviation of the 6 Cryptos

combined_std.plot(kind = 'bar',title='Standard Deviation of the 6 Cryptos')
# Out:
# <AxesSubplot:title={'center':'Standard Deviation of the 6 Cryptos'}>

# %% [markdown]
# # Comparison between _Dollar-Cost Averaging_ and _Lump Sum Investment_ in 5 years time range

# %%
def dca_lump_compare(coin_data):

    # Within 5 years time period, get the close price once every month, calculate the amount by 100/close_price    
    # Get the sum amount and calculate the value by the final (close price * sum_amount)

    # Extract the past 5 years' data from coin_data, time range starts from '2017-09-01' and end '2022-08-01' totally 60 months
    coin_data_slice = coin_data['2017-09-01':'2022-08-01']
    coin_data_slice

    # Group by year and month and get the first price of each month using first() function
    coin_inv_price=coin_data_slice.groupby([coin_data_slice.index.year, coin_data_slice.index.month]).first()
    coin_inv_price
    # Group by year and month and get 

    # Calculate the total amount acquried for the $100 monthly investment

    amount = 0
    total_amount = 0
    i = 0

    coin_inv_price.reset_index(inplace=True)
    coin_inv_price

    df = coin_inv_price.describe()
    count = int(df.iloc[0,0])

    
    while i<count:
        price = coin_inv_price.iloc[i,2]
        amount = round(100/price,4)
        total_amount = round((total_amount + amount),4)
        print(f'Year:{coin_inv_price.iloc[i,0]}, Month:{coin_inv_price.iloc[i,1]}, Pirce:{price}, Amount Acquired:{amount}, Amount Totally Acquired:{total_amount}')
        i += 1

    dca_value = total_amount * price
    print(f'DCA acquired cryptos over the 5-year period valued at:{dca_value} ')

    # investment over 5 years total at $100*60 = $6000
    dca_profit = dca_value - 6000
    print(f'DCA profit over the 5-year period :{dca_profit} ')

    # A Lump Sum Investment Return Calculation

    coin_daily_return = coin_data_slice.pct_change()
    coin_cumprod = (coin_daily_return+1).cumprod()-1
    coin_cumprod.dropna(inplace=True)
    coin_cumprod

    initail_amount = 6000

    cum_return_coin = coin_cumprod.loc['2022-08-01',:]

    cum_return_coin

    lump_sum_profit = initail_amount * cum_return_coin

    print(f'cum_return_coin:{cum_return_coin}')

    print(f'compound_return_coin:{lump_sum_profit}')

    # profit comparison between lump sum Vs. DCA

    print('*****************************************************************************\n')


    print(f'Initial investment of a lump sum of 6000 Vs. Monthly Investment of $100 over 5 years period Comparison\n')

    print(f'DCA profit: {dca_profit}')

    print(f'Lump Sum profit: {lump_sum_profit}')


    print('\n*****************************************************************************')
    
    compare_list = [dca_profit,lump_sum_profit]
    
    return compare_list

# %%
compare_list_btc = dca_lump_compare(btc_data)
compare_list_ada = dca_lump_compare(ada_data)
compare_list_sol = dca_lump_compare(sol_data)
compare_list_xrp = dca_lump_compare(xrp_data)
compare_list_bnb = dca_lump_compare(bnb_data)
compare_list_eth = dca_lump_compare(eth_data)

compare_list = [compare_list_btc,compare_list_eth,compare_list_ada,compare_list_sol,compare_list_xrp,compare_list_bnb]  
                


compare_list
# Out:
# Year:2017, Month:9, Pirce:4947.99, Amount Acquired:0.0202, Amount Totally Acquired:0.0202
# Year:2017, Month:10, Pirce:4394.81, Amount Acquired:0.0228, Amount Totally Acquired:0.043
# Year:2017, Month:11, Pirce:6783.69, Amount Acquired:0.0147, Amount Totally Acquired:0.0577
# Year:2017, Month:12, Pirce:10869.84, Amount Acquired:0.0092, Amount Totally Acquired:0.0669
# Year:2018, Month:1, Pirce:13480.01, Amount Acquired:0.0074, Amount Totally Acquired:0.0743
# Year:2018, Month:2, Pirce:9014.23, Amount Acquired:0.0111, Amount Totally Acquired:0.0854
# Year:2018, Month:3, Pirce:10895.92, Amount Acquired:0.0092, Amount Totally Acquired:0.0946
# Year:2018, Month:4, Pirce:6816.01, Amount Acquired:0.0147, Amount Totally Acquired:0.1093
# Year:2018, Month:5, Pirce:9072.29, Amount Acquired:0.011, Amount Totally Acquired:0.1203
# Year:2018, Month:6, Pirce:7514.32, Amount Acquired:0.0133, Amount Totally Acquired:0.1336
# Year:2018, Month:7, Pirce:6349.5, Amount Acquired:0.0157, Amount Totally Acquired:0.1493
# Year:2018, Month:8, Pirce:7603.99, Amount Acquired:0.0132, Amount Totally Acquired:0.1625
# Year:2018, Month:9, Pirce:7191.08, Amount Acquired:0.0139, Amount Totally Acquired:0.1764
# Year:2018, Month:10, Pirce:6572.83, Amount Acquired:0.0152, Amount Totally Acquired:0.1916
# Year:2018, Month:11, Pirce:6344.0, Amount Acquired:0.0158, Amount Totally Acquired:0.2074
# Year:2018, Month:12, Pirce:4142.01, Amount Acquired:0.0241, Amount Totally Acquired:0.2315
# Year:2019, Month:1, Pirce:3826.1, Amount Acquired:0.0261, Amount Totally Acquired:0.2576
# Year:2019, Month:2, Pirce:3437.5, Amount Acquired:0.0291, Amount Totally Acquired:0.2867
# Year:2019, Month:3, Pirce:3806.17, Amount Acquired:0.0263, Amount Totally Acquired:0.313
# Year:2019, Month:4, Pirce:4137.01, Amount Acquired:0.0242, Amount Totally Acquired:0.3372
# Year:2019, Month:5, Pirce:5321.15, Amount Acquired:0.0188, Amount Totally Acquired:0.356
# Year:2019, Month:6, Pirce:8558.95, Amount Acquired:0.0117, Amount Totally Acquired:0.3677
# Year:2019, Month:7, Pirce:10577.6, Amount Acquired:0.0095, Amount Totally Acquired:0.3772
# Year:2019, Month:8, Pirce:10405.9, Amount Acquired:0.0096, Amount Totally Acquired:0.3868
# Year:2019, Month:9, Pirce:9766.52, Amount Acquired:0.0102, Amount Totally Acquired:0.397
# Year:2019, Month:10, Pirce:8322.73, Amount Acquired:0.012, Amount Totally Acquired:0.409
# Year:2019, Month:11, Pirce:9253.12, Amount Acquired:0.0108, Amount Totally Acquired:0.4198
# Year:2019, Month:12, Pirce:7404.27, Amount Acquired:0.0135, Amount Totally Acquired:0.4333
# Year:2020, Month:1, Pirce:7177.57, Amount Acquired:0.0139, Amount Totally Acquired:0.4472
# Year:2020, Month:2, Pirce:9382.65, Amount Acquired:0.0107, Amount Totally Acquired:0.4579
# Year:2020, Month:3, Pirce:8522.33, Amount Acquired:0.0117, Amount Totally Acquired:0.4696
# Year:2020, Month:4, Pirce:6664.85, Amount Acquired:0.015, Amount Totally Acquired:0.4846
# Year:2020, Month:5, Pirce:8829.42, Amount Acquired:0.0113, Amount Totally Acquired:0.4959
# Year:2020, Month:6, Pirce:10210.1, Amount Acquired:0.0098, Amount Totally Acquired:0.5057
# Year:2020, Month:7, Pirce:9239.96, Amount Acquired:0.0108, Amount Totally Acquired:0.5165
# Year:2020, Month:8, Pirce:11810.0, Amount Acquired:0.0085, Amount Totally Acquired:0.525
# Year:2020, Month:9, Pirce:11929.8, Amount Acquired:0.0084, Amount Totally Acquired:0.5334
# Year:2020, Month:10, Pirce:10612.4, Amount Acquired:0.0094, Amount Totally Acquired:0.5428
# Year:2020, Month:11, Pirce:13748.0, Amount Acquired:0.0073, Amount Totally Acquired:0.5501
# Year:2020, Month:12, Pirce:18870.8, Amount Acquired:0.0053, Amount Totally Acquired:0.5554
# Year:2021, Month:1, Pirce:29388.3, Amount Acquired:0.0034, Amount Totally Acquired:0.5588
# Year:2021, Month:2, Pirce:33533.1, Amount Acquired:0.003, Amount Totally Acquired:0.5618
# Year:2021, Month:3, Pirce:49593.8, Amount Acquired:0.002, Amount Totally Acquired:0.5638
# Year:2021, Month:4, Pirce:58726.4, Amount Acquired:0.0017, Amount Totally Acquired:0.5655
# Year:2021, Month:5, Pirce:57858.2, Amount Acquired:0.0017, Amount Totally Acquired:0.5672
# Year:2021, Month:6, Pirce:36685.0, Amount Acquired:0.0027, Amount Totally Acquired:0.5699
# Year:2021, Month:7, Pirce:33524.5, Amount Acquired:0.003, Amount Totally Acquired:0.5729
# Year:2021, Month:8, Pirce:39865.4, Amount Acquired:0.0025, Amount Totally Acquired:0.5754
# Year:2021, Month:9, Pirce:48839.8, Amount Acquired:0.002, Amount Totally Acquired:0.5774
# Year:2021, Month:10, Pirce:48159.5, Amount Acquired:0.0021, Amount Totally Acquired:0.5795
# Year:2021, Month:11, Pirce:60949.5, Amount Acquired:0.0016, Amount Totally Acquired:0.5811
# Year:2021, Month:12, Pirce:57180.1, Amount Acquired:0.0017, Amount Totally Acquired:0.5828
# Year:2022, Month:1, Pirce:47733.4, Amount Acquired:0.0021, Amount Totally Acquired:0.5849
# Year:2022, Month:2, Pirce:38777.8, Amount Acquired:0.0026, Amount Totally Acquired:0.5875
# Year:2022, Month:3, Pirce:44404.1, Amount Acquired:0.0023, Amount Totally Acquired:0.5898
# Year:2022, Month:4, Pirce:46296.3, Amount Acquired:0.0022, Amount Totally Acquired:0.592
# Year:2022, Month:5, Pirce:38471.6, Amount Acquired:0.0026, Amount Totally Acquired:0.5946
# Year:2022, Month:6, Pirce:29788.7, Amount Acquired:0.0034, Amount Totally Acquired:0.598
# Year:2022, Month:7, Pirce:19247.3, Amount Acquired:0.0052, Amount Totally Acquired:0.6032
# Year:2022, Month:8, Pirce:23273.8, Amount Acquired:0.0043, Amount Totally Acquired:0.6075
# DCA acquired cryptos over the 5-year period valued at:14138.8335
# DCA profit over the 5-year period :8138.833500000001
# cum_return_coin:BTC Close    3.703688
# Name: 2022-08-01 00:00:00, dtype: float64
# compound_return_coin:BTC Close    22222.12656
# Name: 2022-08-01 00:00:00, dtype: float64
# *****************************************************************************
#
# Initial investment of a lump sum of 6000 Vs. Monthly Investment of $100 over 5 years period Comparison
#
# DCA profit: 8138.833500000001
# Lump Sum profit: BTC Close    22222.12656
# Name: 2022-08-01 00:00:00, dtype: float64
#
# *****************************************************************************
# Year:2017, Month:11, Pirce:0.0993751, Amount Acquired:1006.2883, Amount Totally Acquired:1006.2883
# Year:2017, Month:12, Pirce:0.1082012, Amount Acquired:924.2042, Amount Totally Acquired:1930.4925
# Year:2018, Month:1, Pirce:0.679207, Amount Acquired:147.2305, Amount Totally Acquired:2077.723
# Year:2018, Month:2, Pirce:0.42285776, Amount Acquired:236.4861, Amount Totally Acquired:2314.2091
# Year:2018, Month:3, Pirce:0.30633932, Amount Acquired:326.4354, Amount Totally Acquired:2640.6445
# Year:2018, Month:4, Pirce:0.15269342, Amount Acquired:654.9071, Amount Totally Acquired:3295.5516
# Year:2018, Month:5, Pirce:0.3550112475, Amount Acquired:281.6812, Amount Totally Acquired:3577.2328
# Year:2018, Month:6, Pirce:0.2263572915, Amount Acquired:441.7795, Amount Totally Acquired:4019.0123
# Year:2018, Month:7, Pirce:0.1417495002, Amount Acquired:705.4699, Amount Totally Acquired:4724.4822
# Year:2018, Month:8, Pirce:0.1396595783, Amount Acquired:716.0268, Amount Totally Acquired:5440.509
# Year:2018, Month:9, Pirce:0.1069001652, Amount Acquired:935.4522, Amount Totally Acquired:6375.9612
# Year:2018, Month:10, Pirce:0.0842990179, Amount Acquired:1186.2534, Amount Totally Acquired:7562.2146
# Year:2018, Month:11, Pirce:0.07101178873, Amount Acquired:1408.2169, Amount Totally Acquired:8970.4315
# Year:2018, Month:12, Pirce:0.04150935483, Amount Acquired:2409.0955, Amount Totally Acquired:11379.527
# Year:2019, Month:1, Pirce:0.04231813096, Amount Acquired:2363.0533, Amount Totally Acquired:13742.5803
# Year:2019, Month:2, Pirce:0.03837038594, Amount Acquired:2606.1765, Amount Totally Acquired:16348.7568
# Year:2019, Month:3, Pirce:0.04286112408, Amount Acquired:2333.1166, Amount Totally Acquired:18681.8734
# Year:2019, Month:4, Pirce:0.07227035523, Amount Acquired:1383.6932, Amount Totally Acquired:20065.5666
# Year:2019, Month:5, Pirce:0.06841873546, Amount Acquired:1461.588, Amount Totally Acquired:21527.1546
# Year:2019, Month:6, Pirce:0.09036721537, Amount Acquired:1106.596, Amount Totally Acquired:22633.7506
# Year:2019, Month:7, Pirce:0.0832259244, Amount Acquired:1201.5487, Amount Totally Acquired:23835.2993
# Year:2019, Month:8, Pirce:0.05863672226, Amount Acquired:1705.4159, Amount Totally Acquired:25540.7152
# Year:2019, Month:9, Pirce:0.0445122588, Amount Acquired:2246.5721, Amount Totally Acquired:27787.2873
# Year:2019, Month:10, Pirce:0.03835740211, Amount Acquired:2607.0587, Amount Totally Acquired:30394.346
# Year:2019, Month:11, Pirce:0.04219425378, Amount Acquired:2369.991, Amount Totally Acquired:32764.337
# Year:2019, Month:12, Pirce:0.03957231982, Amount Acquired:2527.0189, Amount Totally Acquired:35291.3559
# Year:2020, Month:1, Pirce:0.03332608927, Amount Acquired:3000.6521, Amount Totally Acquired:38292.008
# Year:2020, Month:2, Pirce:0.05599033011, Amount Acquired:1786.0227, Amount Totally Acquired:40078.0307
# Year:2020, Month:3, Pirce:0.0456780646, Amount Acquired:2189.2346, Amount Totally Acquired:42267.2653
# Year:2020, Month:4, Pirce:0.03102641958, Amount Acquired:3223.0596, Amount Totally Acquired:45490.3249
# Year:2020, Month:5, Pirce:0.05086725204, Amount Acquired:1965.9014, Amount Totally Acquired:47456.2263
# Year:2020, Month:6, Pirce:0.08094668526, Amount Acquired:1235.381, Amount Totally Acquired:48691.6073
# Year:2020, Month:7, Pirce:0.09670383066, Amount Acquired:1034.0852, Amount Totally Acquired:49725.6925
# Year:2020, Month:8, Pirce:0.144590262, Amount Acquired:691.6095, Amount Totally Acquired:50417.302
# Year:2020, Month:9, Pirce:0.1245961612, Amount Acquired:802.5929, Amount Totally Acquired:51219.8949
# Year:2020, Month:10, Pirce:0.09791085045, Amount Acquired:1021.3373, Amount Totally Acquired:52241.2322
# Year:2020, Month:11, Pirce:0.09810679824, Amount Acquired:1019.2974, Amount Totally Acquired:53260.5296
# Year:2020, Month:12, Pirce:0.1555392204, Amount Acquired:642.9247, Amount Totally Acquired:53903.4543
# Year:2021, Month:1, Pirce:0.1751921736, Amount Acquired:570.8018, Amount Totally Acquired:54474.2561
# Year:2021, Month:2, Pirce:0.4074880365, Amount Acquired:245.406, Amount Totally Acquired:54719.6621
# Year:2021, Month:3, Pirce:1.295374803, Amount Acquired:77.1977, Amount Totally Acquired:54796.8598
# Year:2021, Month:4, Pirce:1.182537997, Amount Acquired:84.5639, Amount Totally Acquired:54881.4237
# Year:2021, Month:5, Pirce:1.353825114, Amount Acquired:73.8648, Amount Totally Acquired:54955.2885
# Year:2021, Month:6, Pirce:1.735764301, Amount Acquired:57.6115, Amount Totally Acquired:55012.9
# Year:2021, Month:7, Pirce:1.33410769, Amount Acquired:74.9565, Amount Totally Acquired:55087.8565
# Year:2021, Month:8, Pirce:1.313759368, Amount Acquired:76.1174, Amount Totally Acquired:55163.9739
# Year:2021, Month:9, Pirce:2.871161488, Amount Acquired:34.8291, Amount Totally Acquired:55198.803
# Year:2021, Month:10, Pirce:2.256172272, Amount Acquired:44.3229, Amount Totally Acquired:55243.1259
# Year:2021, Month:11, Pirce:1.950196345, Amount Acquired:51.2769, Amount Totally Acquired:55294.4028
# Year:2021, Month:12, Pirce:1.546993028, Amount Acquired:64.6415, Amount Totally Acquired:55359.0443
# Year:2022, Month:1, Pirce:1.374895365, Amount Acquired:72.7328, Amount Totally Acquired:55431.7771
# Year:2022, Month:2, Pirce:1.086068805, Amount Acquired:92.0752, Amount Totally Acquired:55523.8523
# Year:2022, Month:3, Pirce:0.9648419148, Amount Acquired:103.6439, Amount Totally Acquired:55627.4962
# Year:2022, Month:4, Pirce:1.166122454, Amount Acquired:85.7543, Amount Totally Acquired:55713.2505
# Year:2022, Month:5, Pirce:0.7895755183, Amount Acquired:126.6503, Amount Totally Acquired:55839.9008
# Year:2022, Month:6, Pirce:0.5530854889, Amount Acquired:180.8039, Amount Totally Acquired:56020.7047
# Year:2022, Month:7, Pirce:0.4476569364, Amount Acquired:223.3853, Amount Totally Acquired:56244.09
# Year:2022, Month:8, Pirce:0.5129765932, Amount Acquired:194.9407, Amount Totally Acquired:56439.0307
# DCA acquired cryptos over the 5-year period valued at:28951.901691996212
# DCA profit over the 5-year period :22951.901691996212
# cum_return_coin:ADA Close    4.162023
# Name: 2022-08-01 00:00:00, dtype: float64
# compound_return_coin:ADA Close    24972.140498
# Name: 2022-08-01 00:00:00, dtype: float64
# *****************************************************************************
#
# Initial investment of a lump sum of 6000 Vs. Monthly Investment of $100 over 5 years period Comparison
#
# DCA profit: 22951.901691996212
# Lump Sum profit: ADA Close    24972.140498
# Name: 2022-08-01 00:00:00, dtype: float64
#
# *****************************************************************************
# Year:2017, Month:9, Pirce:3.3, Amount Acquired:30.303, Amount Totally Acquired:30.303
# Year:2017, Month:10, Pirce:3.31, Amount Acquired:30.2115, Amount Totally Acquired:60.5145
# Year:2017, Month:11, Pirce:3.4, Amount Acquired:29.4118, Amount Totally Acquired:89.9263
# Year:2017, Month:12, Pirce:3.38, Amount Acquired:29.5858, Amount Totally Acquired:119.5121
# Year:2018, Month:1, Pirce:3.03, Amount Acquired:33.0033, Amount Totally Acquired:152.5154
# Year:2018, Month:2, Pirce:2.95, Amount Acquired:33.8983, Amount Totally Acquired:186.4137
# Year:2018, Month:3, Pirce:2.82, Amount Acquired:35.461, Amount Totally Acquired:221.8747
# Year:2018, Month:4, Pirce:2.81, Amount Acquired:35.5872, Amount Totally Acquired:257.4619
# Year:2018, Month:5, Pirce:3.1, Amount Acquired:32.2581, Amount Totally Acquired:289.72
# Year:2018, Month:6, Pirce:2.55, Amount Acquired:39.2157, Amount Totally Acquired:328.9357
# Year:2018, Month:7, Pirce:2.48, Amount Acquired:40.3226, Amount Totally Acquired:369.2583
# Year:2018, Month:8, Pirce:3.15, Amount Acquired:31.746, Amount Totally Acquired:401.0043
# Year:2018, Month:9, Pirce:3.03, Amount Acquired:33.0033, Amount Totally Acquired:434.0076
# Year:2018, Month:10, Pirce:3.0, Amount Acquired:33.3333, Amount Totally Acquired:467.3409
# Year:2018, Month:11, Pirce:3.07, Amount Acquired:32.5733, Amount Totally Acquired:499.9142
# Year:2018, Month:12, Pirce:3.06, Amount Acquired:32.6797, Amount Totally Acquired:532.5939
# Year:2019, Month:1, Pirce:1.56, Amount Acquired:64.1026, Amount Totally Acquired:596.6965
# Year:2019, Month:2, Pirce:1.25, Amount Acquired:80.0, Amount Totally Acquired:676.6965
# Year:2019, Month:3, Pirce:1.25, Amount Acquired:80.0, Amount Totally Acquired:756.6965
# Year:2019, Month:4, Pirce:1.33, Amount Acquired:75.188, Amount Totally Acquired:831.8845
# Year:2019, Month:5, Pirce:1.7, Amount Acquired:58.8235, Amount Totally Acquired:890.708
# Year:2019, Month:6, Pirce:1.77, Amount Acquired:56.4972, Amount Totally Acquired:947.2052
# Year:2019, Month:7, Pirce:1.36, Amount Acquired:73.5294, Amount Totally Acquired:1020.7346
# Year:2019, Month:8, Pirce:1.36, Amount Acquired:73.5294, Amount Totally Acquired:1094.264
# Year:2019, Month:9, Pirce:1.35, Amount Acquired:74.0741, Amount Totally Acquired:1168.3381
# Year:2019, Month:10, Pirce:1.46, Amount Acquired:68.4932, Amount Totally Acquired:1236.8313
# Year:2019, Month:11, Pirce:1.46, Amount Acquired:68.4932, Amount Totally Acquired:1305.3245
# Year:2019, Month:12, Pirce:1.7, Amount Acquired:58.8235, Amount Totally Acquired:1364.148
# Year:2020, Month:1, Pirce:1.39, Amount Acquired:71.9424, Amount Totally Acquired:1436.0904
# Year:2020, Month:2, Pirce:1.4, Amount Acquired:71.4286, Amount Totally Acquired:1507.519
# Year:2020, Month:3, Pirce:1.39, Amount Acquired:71.9424, Amount Totally Acquired:1579.4614
# Year:2020, Month:4, Pirce:1.34, Amount Acquired:74.6269, Amount Totally Acquired:1654.0883
# Year:2020, Month:5, Pirce:1.38, Amount Acquired:72.4638, Amount Totally Acquired:1726.5521
# Year:2020, Month:6, Pirce:1.32, Amount Acquired:75.7576, Amount Totally Acquired:1802.3097
# Year:2020, Month:7, Pirce:1.3, Amount Acquired:76.9231, Amount Totally Acquired:1879.2328
# Year:2020, Month:8, Pirce:1.32, Amount Acquired:75.7576, Amount Totally Acquired:1954.9904
# Year:2020, Month:9, Pirce:1.35, Amount Acquired:74.0741, Amount Totally Acquired:2029.0645
# Year:2020, Month:10, Pirce:1.36, Amount Acquired:73.5294, Amount Totally Acquired:2102.5939
# Year:2020, Month:11, Pirce:1.34, Amount Acquired:74.6269, Amount Totally Acquired:2177.2208
# Year:2020, Month:12, Pirce:1.49, Amount Acquired:67.1141, Amount Totally Acquired:2244.3349
# Year:2021, Month:1, Pirce:22.27, Amount Acquired:4.4903, Amount Totally Acquired:2248.8252
# Year:2021, Month:2, Pirce:23.63, Amount Acquired:4.2319, Amount Totally Acquired:2253.0571
# Year:2021, Month:3, Pirce:24.51, Amount Acquired:4.08, Amount Totally Acquired:2257.1371
# Year:2021, Month:4, Pirce:12.77, Amount Acquired:7.8309, Amount Totally Acquired:2264.968
# Year:2021, Month:5, Pirce:14.72, Amount Acquired:6.7935, Amount Totally Acquired:2271.7615
# Year:2021, Month:6, Pirce:16.83, Amount Acquired:5.9418, Amount Totally Acquired:2277.7033
# Year:2021, Month:7, Pirce:18.01, Amount Acquired:5.5525, Amount Totally Acquired:2283.2558
# Year:2021, Month:8, Pirce:20.87, Amount Acquired:4.7916, Amount Totally Acquired:2288.0474
# Year:2021, Month:9, Pirce:24.15, Amount Acquired:4.1408, Amount Totally Acquired:2292.1882
# Year:2021, Month:10, Pirce:24.4, Amount Acquired:4.0984, Amount Totally Acquired:2296.2866
# Year:2021, Month:11, Pirce:20.14, Amount Acquired:4.9652, Amount Totally Acquired:2301.2518
# Year:2021, Month:12, Pirce:23.25, Amount Acquired:4.3011, Amount Totally Acquired:2305.5529
# Year:2022, Month:1, Pirce:6.17, Amount Acquired:16.2075, Amount Totally Acquired:2321.7604
# Year:2022, Month:2, Pirce:5.23, Amount Acquired:19.1205, Amount Totally Acquired:2340.8809
# Year:2022, Month:3, Pirce:6.15, Amount Acquired:16.2602, Amount Totally Acquired:2357.1411
# Year:2022, Month:4, Pirce:6.13, Amount Acquired:16.3132, Amount Totally Acquired:2373.4543
# Year:2022, Month:5, Pirce:6.17, Amount Acquired:16.2075, Amount Totally Acquired:2389.6618
# Year:2022, Month:6, Pirce:6.0, Amount Acquired:16.6667, Amount Totally Acquired:2406.3285
# Year:2022, Month:7, Pirce:6.37, Amount Acquired:15.6986, Amount Totally Acquired:2422.0271
# DCA acquired cryptos over the 5-year period valued at:15428.312627
# DCA profit over the 5-year period :9428.312627
# cum_return_coin:Empty DataFrame
# Columns: [SOL Close]
# Index: []
# compound_return_coin:Empty DataFrame
# Columns: [SOL Close]
# Index: []
# *****************************************************************************
#
# Initial investment of a lump sum of 6000 Vs. Monthly Investment of $100 over 5 years period Comparison
#
# DCA profit: 9428.312627
# Lump Sum profit: Empty DataFrame
# Columns: [SOL Close]
# Index: []
#
# *****************************************************************************
# Year:2017, Month:10, Pirce:0.1774146, Amount Acquired:563.6515, Amount Totally Acquired:563.6515
# Year:2017, Month:11, Pirce:0.131354, Amount Acquired:761.3015, Amount Totally Acquired:1324.953
# Year:2017, Month:12, Pirce:0.2164024, Amount Acquired:462.1021, Amount Totally Acquired:1787.0551
# Year:2018, Month:1, Pirce:1.9017796, Amount Acquired:52.5823, Amount Totally Acquired:1839.6374
# Year:2018, Month:2, Pirce:0.9652188, Amount Acquired:103.6035, Amount Totally Acquired:1943.2409
# Year:2018, Month:3, Pirce:0.91901796, Amount Acquired:108.8118, Amount Totally Acquired:2052.0527
# Year:2018, Month:4, Pirce:0.49972392, Amount Acquired:200.1105, Amount Totally Acquired:2252.1632
# Year:2018, Month:5, Pirce:0.8366501325, Amount Acquired:119.5243, Amount Totally Acquired:2371.6875
# Year:2018, Month:6, Pirce:0.6423508434, Amount Acquired:155.6782, Amount Totally Acquired:2527.3657
# Year:2018, Month:7, Pirce:0.4607969646, Amount Acquired:217.0153, Amount Totally Acquired:2744.381
# Year:2018, Month:8, Pirce:0.4461199812, Amount Acquired:224.1549, Amount Totally Acquired:2968.5359
# Year:2018, Month:9, Pirce:0.346382433, Amount Acquired:288.6982, Amount Totally Acquired:3257.2341
# Year:2018, Month:10, Pirce:0.5757906336, Amount Acquired:173.6742, Amount Totally Acquired:3430.9083
# Year:2018, Month:11, Pirce:0.4586553163, Amount Acquired:218.0287, Amount Totally Acquired:3648.937
# Year:2018, Month:12, Pirce:0.3738831855, Amount Acquired:267.4632, Amount Totally Acquired:3916.4002
# Year:2019, Month:1, Pirce:0.3636143774, Amount Acquired:275.0166, Amount Totally Acquired:4191.4168
# Year:2019, Month:2, Pirce:0.3050205889, Amount Acquired:327.8467, Amount Totally Acquired:4519.2635
# Year:2019, Month:3, Pirce:0.3144253669, Amount Acquired:318.0405, Amount Totally Acquired:4837.304
# Year:2019, Month:4, Pirce:0.3130330983, Amount Acquired:319.455, Amount Totally Acquired:5156.759
# Year:2019, Month:5, Pirce:0.3011719723, Amount Acquired:332.0362, Amount Totally Acquired:5488.7952
# Year:2019, Month:6, Pirce:0.4291886808, Amount Acquired:232.9978, Amount Totally Acquired:5721.793
# Year:2019, Month:7, Pirce:0.4053293112, Amount Acquired:246.713, Amount Totally Acquired:5968.506
# Year:2019, Month:8, Pirce:0.3162410098, Amount Acquired:316.2145, Amount Totally Acquired:6284.7205
# Year:2019, Month:9, Pirce:0.2571308848, Amount Acquired:388.907, Amount Totally Acquired:6673.6275
# Year:2019, Month:10, Pirce:0.2484823807, Amount Acquired:402.443, Amount Totally Acquired:7076.0705
# Year:2019, Month:11, Pirce:0.2919716464, Amount Acquired:342.499, Amount Totally Acquired:7418.5695
# Year:2019, Month:12, Pirce:0.2252321445, Amount Acquired:443.9864, Amount Totally Acquired:7862.5559
# Year:2020, Month:1, Pirce:0.1922465542, Amount Acquired:520.1654, Amount Totally Acquired:8382.7213
# Year:2020, Month:2, Pirce:0.2409169977, Amount Acquired:415.0807, Amount Totally Acquired:8797.802
# Year:2020, Month:3, Pirce:0.2271010916, Amount Acquired:440.3325, Amount Totally Acquired:9238.1345
# Year:2020, Month:4, Pirce:0.1755987418, Amount Acquired:569.4802, Amount Totally Acquired:9807.6147
# Year:2020, Month:5, Pirce:0.2177679754, Amount Acquired:459.2043, Amount Totally Acquired:10266.819
# Year:2020, Month:6, Pirce:0.2110085808, Amount Acquired:473.9144, Amount Totally Acquired:10740.7334
# Year:2020, Month:7, Pirce:0.1764313823, Amount Acquired:566.7926, Amount Totally Acquired:11307.526
# Year:2020, Month:8, Pirce:0.290845875, Amount Acquired:343.8247, Amount Totally Acquired:11651.3507
# Year:2020, Month:9, Pirce:0.2951288092, Amount Acquired:338.8351, Amount Totally Acquired:11990.1858
# Year:2020, Month:10, Pirce:0.2380914899, Amount Acquired:420.0066, Amount Totally Acquired:12410.1924
# Year:2020, Month:11, Pirce:0.2398991994, Amount Acquired:416.8417, Amount Totally Acquired:12827.0341
# Year:2020, Month:12, Pirce:0.6114306865, Amount Acquired:163.5508, Amount Totally Acquired:12990.5849
# Year:2021, Month:1, Pirce:0.2374206688, Amount Acquired:421.1933, Amount Totally Acquired:13411.7782
# Year:2021, Month:2, Pirce:0.3717364112, Amount Acquired:269.0078, Amount Totally Acquired:13680.786
# Year:2021, Month:3, Pirce:0.4450711359, Amount Acquired:224.6832, Amount Totally Acquired:13905.4692
# Year:2021, Month:4, Pirce:0.5703053446, Amount Acquired:175.3447, Amount Totally Acquired:14080.8139
# Year:2021, Month:5, Pirce:1.649110506, Amount Acquired:60.6388, Amount Totally Acquired:14141.4527
# Year:2021, Month:6, Pirce:1.011055743, Amount Acquired:98.9065, Amount Totally Acquired:14240.3592
# Year:2021, Month:7, Pirce:0.6606293821, Amount Acquired:151.3708, Amount Totally Acquired:14391.73
# Year:2021, Month:8, Pirce:0.7244667945, Amount Acquired:138.0326, Amount Totally Acquired:14529.7626
# Year:2021, Month:9, Pirce:1.237338765, Amount Acquired:80.8186, Amount Totally Acquired:14610.5812
# Year:2021, Month:10, Pirce:1.041932448, Amount Acquired:95.9755, Amount Totally Acquired:14706.5567
# Year:2021, Month:11, Pirce:1.093388939, Amount Acquired:91.4588, Amount Totally Acquired:14798.0155
# Year:2021, Month:12, Pirce:0.9901373238, Amount Acquired:100.9961, Amount Totally Acquired:14899.0116
# Year:2022, Month:1, Pirce:0.8504289251, Amount Acquired:117.5877, Amount Totally Acquired:15016.5993
# Year:2022, Month:2, Pirce:0.6290009731, Amount Acquired:158.9823, Amount Totally Acquired:15175.5816
# Year:2022, Month:3, Pirce:0.7866215761, Amount Acquired:127.1259, Amount Totally Acquired:15302.7075
# Year:2022, Month:4, Pirce:0.828009893, Amount Acquired:120.7715, Amount Totally Acquired:15423.479
# Year:2022, Month:5, Pirce:0.6078630932, Amount Acquired:164.5107, Amount Totally Acquired:15587.9897
# Year:2022, Month:6, Pirce:0.3978093851, Amount Acquired:251.3767, Amount Totally Acquired:15839.3664
# Year:2022, Month:7, Pirce:0.31340221, Amount Acquired:319.0788, Amount Totally Acquired:16158.4452
# Year:2022, Month:8, Pirce:0.3797704096, Amount Acquired:263.317, Amount Totally Acquired:16421.7622
# DCA acquired cryptos over the 5-year period valued at:6236.499357047798
# DCA profit over the 5-year period :236.49935704779818
# cum_return_coin:XRP Close    1.140581
# Name: 2022-08-01 00:00:00, dtype: float64
# compound_return_coin:XRP Close    6843.488967
# Name: 2022-08-01 00:00:00, dtype: float64
# *****************************************************************************
#
# Initial investment of a lump sum of 6000 Vs. Monthly Investment of $100 over 5 years period Comparison
#
# DCA profit: 236.49935704779818
# Lump Sum profit: XRP Close    6843.488967
# Name: 2022-08-01 00:00:00, dtype: float64
#
# *****************************************************************************
# Year:2017, Month:9, Pirce:3024.95, Amount Acquired:0.0331, Amount Totally Acquired:0.0331
# Year:2017, Month:10, Pirce:3014.7, Amount Acquired:0.0332, Amount Totally Acquired:0.0663
# Year:2017, Month:11, Pirce:3030.0, Amount Acquired:0.033, Amount Totally Acquired:0.0993
# Year:2017, Month:12, Pirce:3001.0, Amount Acquired:0.0333, Amount Totally Acquired:0.1326
# Year:2018, Month:1, Pirce:2900.0, Amount Acquired:0.0345, Amount Totally Acquired:0.1671
# Year:2018, Month:2, Pirce:2860.0, Amount Acquired:0.035, Amount Totally Acquired:0.2021
# Year:2018, Month:3, Pirce:2890.0, Amount Acquired:0.0346, Amount Totally Acquired:0.2367
# Year:2018, Month:4, Pirce:2890.0, Amount Acquired:0.0346, Amount Totally Acquired:0.2713
# Year:2018, Month:5, Pirce:2880.0, Amount Acquired:0.0347, Amount Totally Acquired:0.306
# Year:2018, Month:6, Pirce:2960.0, Amount Acquired:0.0338, Amount Totally Acquired:0.3398
# Year:2018, Month:7, Pirce:2980.0, Amount Acquired:0.0336, Amount Totally Acquired:0.3734
# Year:2018, Month:8, Pirce:2890.0, Amount Acquired:0.0346, Amount Totally Acquired:0.408
# Year:2018, Month:9, Pirce:2900.0, Amount Acquired:0.0345, Amount Totally Acquired:0.4425
# Year:2018, Month:10, Pirce:2900.0, Amount Acquired:0.0345, Amount Totally Acquired:0.477
# Year:2018, Month:11, Pirce:2890.0, Amount Acquired:0.0346, Amount Totally Acquired:0.5116
# Year:2018, Month:12, Pirce:2880.0, Amount Acquired:0.0347, Amount Totally Acquired:0.5463
# Year:2019, Month:1, Pirce:2440.0, Amount Acquired:0.041, Amount Totally Acquired:0.5873
# Year:2019, Month:2, Pirce:2420.0, Amount Acquired:0.0413, Amount Totally Acquired:0.6286
# Year:2019, Month:3, Pirce:2430.0, Amount Acquired:0.0412, Amount Totally Acquired:0.6698
# Year:2019, Month:4, Pirce:2440.0, Amount Acquired:0.041, Amount Totally Acquired:0.7108
# Year:2019, Month:5, Pirce:2480.0, Amount Acquired:0.0403, Amount Totally Acquired:0.7511
# Year:2019, Month:6, Pirce:2470.0, Amount Acquired:0.0405, Amount Totally Acquired:0.7916
# Year:2019, Month:7, Pirce:2470.0, Amount Acquired:0.0405, Amount Totally Acquired:0.8321
# Year:2019, Month:8, Pirce:2460.0, Amount Acquired:0.0407, Amount Totally Acquired:0.8728
# Year:2019, Month:9, Pirce:2480.0, Amount Acquired:0.0403, Amount Totally Acquired:0.9131
# Year:2019, Month:10, Pirce:2470.0, Amount Acquired:0.0405, Amount Totally Acquired:0.9536
# Year:2019, Month:11, Pirce:2420.0, Amount Acquired:0.0413, Amount Totally Acquired:0.9949
# Year:2019, Month:12, Pirce:2450.0, Amount Acquired:0.0408, Amount Totally Acquired:1.0357
# Year:2020, Month:1, Pirce:2350.0, Amount Acquired:0.0426, Amount Totally Acquired:1.0783
# Year:2020, Month:2, Pirce:2390.0, Amount Acquired:0.0418, Amount Totally Acquired:1.1201
# Year:2020, Month:3, Pirce:2410.0, Amount Acquired:0.0415, Amount Totally Acquired:1.1616
# Year:2020, Month:4, Pirce:2350.0, Amount Acquired:0.0426, Amount Totally Acquired:1.2042
# Year:2020, Month:5, Pirce:2350.0, Amount Acquired:0.0426, Amount Totally Acquired:1.2468
# Year:2020, Month:6, Pirce:2380.0, Amount Acquired:0.042, Amount Totally Acquired:1.2888
# Year:2020, Month:7, Pirce:2390.0, Amount Acquired:0.0418, Amount Totally Acquired:1.3306
# Year:2020, Month:8, Pirce:2400.0, Amount Acquired:0.0417, Amount Totally Acquired:1.3723
# Year:2020, Month:9, Pirce:2370.0, Amount Acquired:0.0422, Amount Totally Acquired:1.4145
# Year:2020, Month:10, Pirce:2380.0, Amount Acquired:0.042, Amount Totally Acquired:1.4565
# Year:2020, Month:11, Pirce:2380.0, Amount Acquired:0.042, Amount Totally Acquired:1.4985
# Year:2020, Month:12, Pirce:2390.0, Amount Acquired:0.0418, Amount Totally Acquired:1.5403
# Year:2021, Month:1, Pirce:1805.0, Amount Acquired:0.0554, Amount Totally Acquired:1.5957
# Year:2021, Month:2, Pirce:1795.0, Amount Acquired:0.0557, Amount Totally Acquired:1.6514
# Year:2021, Month:3, Pirce:1805.0, Amount Acquired:0.0554, Amount Totally Acquired:1.7068
# Year:2021, Month:4, Pirce:1750.0, Amount Acquired:0.0571, Amount Totally Acquired:1.7639
# Year:2021, Month:5, Pirce:1770.0, Amount Acquired:0.0565, Amount Totally Acquired:1.8204
# Year:2021, Month:6, Pirce:1785.0, Amount Acquired:0.056, Amount Totally Acquired:1.8764
# Year:2021, Month:7, Pirce:1760.0, Amount Acquired:0.0568, Amount Totally Acquired:1.9332
# Year:2021, Month:8, Pirce:1765.0, Amount Acquired:0.0567, Amount Totally Acquired:1.9899
# Year:2021, Month:9, Pirce:1805.0, Amount Acquired:0.0554, Amount Totally Acquired:2.0453
# Year:2021, Month:10, Pirce:1810.0, Amount Acquired:0.0552, Amount Totally Acquired:2.1005
# Year:2021, Month:11, Pirce:1755.0, Amount Acquired:0.057, Amount Totally Acquired:2.1575
# Year:2021, Month:12, Pirce:1820.0, Amount Acquired:0.0549, Amount Totally Acquired:2.2124
# Year:2022, Month:1, Pirce:1665.0, Amount Acquired:0.0601, Amount Totally Acquired:2.2725
# Year:2022, Month:2, Pirce:1695.0, Amount Acquired:0.059, Amount Totally Acquired:2.3315
# Year:2022, Month:3, Pirce:1650.0, Amount Acquired:0.0606, Amount Totally Acquired:2.3921
# Year:2022, Month:4, Pirce:1665.0, Amount Acquired:0.0601, Amount Totally Acquired:2.4522
# Year:2022, Month:5, Pirce:1670.0, Amount Acquired:0.0599, Amount Totally Acquired:2.5121
# Year:2022, Month:6, Pirce:1660.0, Amount Acquired:0.0602, Amount Totally Acquired:2.5723
# Year:2022, Month:7, Pirce:1655.0, Amount Acquired:0.0604, Amount Totally Acquired:2.6327
# DCA acquired cryptos over the 5-year period valued at:4357.1185
# DCA profit over the 5-year period :-1642.8815000000004
# cum_return_coin:Empty DataFrame
# Columns: [BNB Close]
# Index: []
# compound_return_coin:Empty DataFrame
# Columns: [BNB Close]
# Index: []
# *****************************************************************************
#
# Initial investment of a lump sum of 6000 Vs. Monthly Investment of $100 over 5 years period Comparison
#
# DCA profit: -1642.8815000000004
# Lump Sum profit: Empty DataFrame
# Columns: [BNB Close]
# Index: []
#
# *****************************************************************************
# Year:2017, Month:9, Pirce:392.87, Amount Acquired:0.2545, Amount Totally Acquired:0.2545
# Year:2017, Month:10, Pirce:303.25, Amount Acquired:0.3298, Amount Totally Acquired:0.5843
# Year:2017, Month:11, Pirce:290.82, Amount Acquired:0.3439, Amount Totally Acquired:0.9282
# Year:2017, Month:12, Pirce:463.82, Amount Acquired:0.2156, Amount Totally Acquired:1.1438
# Year:2018, Month:1, Pirce:759.03, Amount Acquired:0.1317, Amount Totally Acquired:1.2755
# Year:2018, Month:2, Pirce:1017.48, Amount Acquired:0.0983, Amount Totally Acquired:1.3738
# Year:2018, Month:3, Pirce:868.74, Amount Acquired:0.1151, Amount Totally Acquired:1.4889
# Year:2018, Month:4, Pirce:378.18, Amount Acquired:0.2644, Amount Totally Acquired:1.7533
# Year:2018, Month:5, Pirce:670.75, Amount Acquired:0.1491, Amount Totally Acquired:1.9024
# Year:2018, Month:6, Pirce:578.89, Amount Acquired:0.1727, Amount Totally Acquired:2.0751
# Year:2018, Month:7, Pirce:451.43, Amount Acquired:0.2215, Amount Totally Acquired:2.2966
# Year:2018, Month:8, Pirce:419.6, Amount Acquired:0.2383, Amount Totally Acquired:2.5349
# Year:2018, Month:9, Pirce:294.64, Amount Acquired:0.3394, Amount Totally Acquired:2.8743
# Year:2018, Month:10, Pirce:230.4, Amount Acquired:0.434, Amount Totally Acquired:3.3083
# Year:2018, Month:11, Pirce:197.96, Amount Acquired:0.5052, Amount Totally Acquired:3.8135
# Year:2018, Month:12, Pirce:116.82, Amount Acquired:0.856, Amount Totally Acquired:4.6695
# Year:2019, Month:1, Pirce:139.75, Amount Acquired:0.7156, Amount Totally Acquired:5.3851
# Year:2019, Month:2, Pirce:105.88, Amount Acquired:0.9445, Amount Totally Acquired:6.3296
# Year:2019, Month:3, Pirce:134.72, Amount Acquired:0.7423, Amount Totally Acquired:7.0719
# Year:2019, Month:4, Pirce:141.0, Amount Acquired:0.7092, Amount Totally Acquired:7.7811
# Year:2019, Month:5, Pirce:158.39, Amount Acquired:0.6314, Amount Totally Acquired:8.4125
# Year:2019, Month:6, Pirce:264.78, Amount Acquired:0.3777, Amount Totally Acquired:8.7902
# Year:2019, Month:7, Pirce:294.15, Amount Acquired:0.34, Amount Totally Acquired:9.1302
# Year:2019, Month:8, Pirce:217.55, Amount Acquired:0.4597, Amount Totally Acquired:9.5899
# Year:2019, Month:9, Pirce:171.29, Amount Acquired:0.5838, Amount Totally Acquired:10.1737
# Year:2019, Month:10, Pirce:176.15, Amount Acquired:0.5677, Amount Totally Acquired:10.7414
# Year:2019, Month:11, Pirce:183.19, Amount Acquired:0.5459, Amount Totally Acquired:11.2873
# Year:2019, Month:12, Pirce:151.47, Amount Acquired:0.6602, Amount Totally Acquired:11.9475
# Year:2020, Month:1, Pirce:130.27, Amount Acquired:0.7676, Amount Totally Acquired:12.7151
# Year:2020, Month:2, Pirce:183.68, Amount Acquired:0.5444, Amount Totally Acquired:13.2595
# Year:2020, Month:3, Pirce:218.18, Amount Acquired:0.4583, Amount Totally Acquired:13.7178
# Year:2020, Month:4, Pirce:136.16, Amount Acquired:0.7344, Amount Totally Acquired:14.4522
# Year:2020, Month:5, Pirce:212.09, Amount Acquired:0.4715, Amount Totally Acquired:14.9237
# Year:2020, Month:6, Pirce:247.98, Amount Acquired:0.4033, Amount Totally Acquired:15.327
# Year:2020, Month:7, Pirce:231.03, Amount Acquired:0.4328, Amount Totally Acquired:15.7598
# Year:2020, Month:8, Pirce:387.4, Amount Acquired:0.2581, Amount Totally Acquired:16.0179
# Year:2020, Month:9, Pirce:475.57, Amount Acquired:0.2103, Amount Totally Acquired:16.2282
# Year:2020, Month:10, Pirce:352.75, Amount Acquired:0.2835, Amount Totally Acquired:16.5117
# Year:2020, Month:11, Pirce:395.89, Amount Acquired:0.2526, Amount Totally Acquired:16.7643
# Year:2020, Month:12, Pirce:589.88, Amount Acquired:0.1695, Amount Totally Acquired:16.9338
# Year:2021, Month:1, Pirce:730.99, Amount Acquired:0.1368, Amount Totally Acquired:17.0706
# Year:2021, Month:2, Pirce:1374.85, Amount Acquired:0.0727, Amount Totally Acquired:17.1433
# Year:2021, Month:3, Pirce:1569.09, Amount Acquired:0.0637, Amount Totally Acquired:17.207
# Year:2021, Month:4, Pirce:1968.38, Amount Acquired:0.0508, Amount Totally Acquired:17.2578
# Year:2021, Month:5, Pirce:2948.92, Amount Acquired:0.0339, Amount Totally Acquired:17.2917
# Year:2021, Month:6, Pirce:2634.42, Amount Acquired:0.038, Amount Totally Acquired:17.3297
# Year:2021, Month:7, Pirce:2116.1, Amount Acquired:0.0473, Amount Totally Acquired:17.377
# Year:2021, Month:8, Pirce:2569.57, Amount Acquired:0.0389, Amount Totally Acquired:17.4159
# Year:2021, Month:9, Pirce:3817.15, Amount Acquired:0.0262, Amount Totally Acquired:17.4421
# Year:2021, Month:10, Pirce:3306.19, Amount Acquired:0.0302, Amount Totally Acquired:17.4723
# Year:2021, Month:11, Pirce:4322.64, Amount Acquired:0.0231, Amount Totally Acquired:17.4954
# Year:2021, Month:12, Pirce:4579.79, Amount Acquired:0.0218, Amount Totally Acquired:17.5172
# Year:2022, Month:1, Pirce:3767.54, Amount Acquired:0.0265, Amount Totally Acquired:17.5437
# Year:2022, Month:2, Pirce:2796.73, Amount Acquired:0.0358, Amount Totally Acquired:17.5795
# Year:2022, Month:3, Pirce:2973.34, Amount Acquired:0.0336, Amount Totally Acquired:17.6131
# Year:2022, Month:4, Pirce:3448.0, Amount Acquired:0.029, Amount Totally Acquired:17.6421
# Year:2022, Month:5, Pirce:2824.86, Amount Acquired:0.0354, Amount Totally Acquired:17.6775
# Year:2022, Month:6, Pirce:1816.05, Amount Acquired:0.0551, Amount Totally Acquired:17.7326
# Year:2022, Month:7, Pirce:1057.57, Amount Acquired:0.0946, Amount Totally Acquired:17.8272
# Year:2022, Month:8, Pirce:1630.63, Amount Acquired:0.0613, Amount Totally Acquired:17.8885
# DCA acquired cryptos over the 5-year period valued at:29169.524755000002
# DCA profit over the 5-year period :23169.524755000002
# cum_return_coin:ETH Close    3.150559
# Name: 2022-08-01 00:00:00, dtype: float64
# compound_return_coin:ETH Close    18903.352254
# Name: 2022-08-01 00:00:00, dtype: float64
# *****************************************************************************
#
# Initial investment of a lump sum of 6000 Vs. Monthly Investment of $100 over 5 years period Comparison
#
# DCA profit: 23169.524755000002
# Lump Sum profit: ETH Close    18903.352254
# Name: 2022-08-01 00:00:00, dtype: float64
#
# *****************************************************************************
# [[8138.833500000001,
#   BTC Close    22222.12656
#   Name: 2022-08-01 00:00:00, dtype: float64],
#  [23169.524755000002,
#   ETH Close    18903.352254
#   Name: 2022-08-01 00:00:00, dtype: float64],
#  [22951.901691996212,
#   ADA Close    24972.140498
#   Name: 2022-08-01 00:00:00, dtype: float64],
#  [9428.312627,
#   Empty DataFrame
#   Columns: [SOL Close]
#   Index: []],
#  [236.49935704779818,
#   XRP Close    6843.488967
#   Name: 2022-08-01 00:00:00, dtype: float64],
#  [-1642.8815000000004,
#   Empty DataFrame
#   Columns: [BNB Close]
#   Index: []]]
